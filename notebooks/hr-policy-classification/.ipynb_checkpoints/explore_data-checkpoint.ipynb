# %%
data_dir = "/Users/erikbeerepoot/Dropbox/data/policies/"
nlp = spacy.load('en_core_web_lg')

# %%
from pathlib import Path
import itertools

def get_files(data_dir,extension=".md"):
    """ Crawl directories and return list of markdown files"""
    p = Path(data_dir)
    dirs = [f for f in p.iterdir() if f.is_dir()]
    all_files = [list(dir.glob(f"**/*{extension}")) for dir in dirs]
    
    file_map = dict()
    for dir in dirs:
        file_map[dir.name] = all_files[dirs.index(dir)]            
    print(f"Found {len(list(itertools.chain(*all_files)))} files in {len(dirs)} directories. ")
    return file_map

# %%
def load_tags(data_dir):
    tag_files = get_files(data_dir,".json")
    
    tags = dict([])
    for k,v in tag_files.items():
        if(len(v) < 1):
            continue
        tags[k] = json.loads(open(v[0],'r').read())
    return tags

# %%
import itertools

def get_all_tags(data_dir):
    """Returns a list of (unique) tags in the corpus"""
    tags = load_tags(data_dir)
    all_tags = []
    for key,value in tags.items():
        all_tags.append([tag["tags"] for tag in value]) 
    all_tags = list(itertools.chain(*list(itertools.chain(*all_tags))))
    return sorted(list(set(all_tags)))

# %%
def load_data(file_paths):
    """Load data from a list of files"""
    file_handles = [open(file) for file in file_paths]
    return ["".join(fh.readlines()) for fh in file_handles]

# %%
import spacy 
import string

punctuation = string.punctuation

def cleanup_files(files):    
    """ Cleanup data files by lemmatizing, lowercasing, stripping whitespace,
    removing punctuation and removing stopwords."""
    cleaner_files = []
    for file in files:
        doc = nlp(file)
        tokens = [token.lower_.strip() for token in doc if not token.is_stop]
        cleaner_files.append([token for token in tokens if token not in punctuation])
    return cleaner_files

# %%
import simplejson as json

def generate_tags_template(files):
    file_names = sorted([file.name for file in files])
    tags = "".join([f"""{{"file" : "{name}", "tags" : [ ] }},""" for name in file_names])
    tags = f"[ {tags[:-1]}]"
    parent_dir = next(iter(files)).parent
    fh = open(f"{parent_dir}/tags.json","w+")
    fh.write(json.dumps(json.loads(tags), indent=4, sort_keys=True))
    fh.close()

# %%
import spacy 
import itertools

nlp = spacy.load('en_core_web_lg')

files = get_files(data_dir)
file_contents = load_data(files["york"])
tags = load_tags(data_dir)
# Out:
# Found 1126 files in 10 directories.
# Found 3 files in 10 directories.
# /Users/erikbeerepoot/Dropbox/data/policies/stanford/tags.json
# /Users/erikbeerepoot/Dropbox/data/policies/yale/tags.json
# /Users/erikbeerepoot/Dropbox/data/policies/columbia/tags.json

# %% [markdown]
# This can take a bit of time:

# %%
files = cleanup_files(file_contents)

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
import matplotlib.pyplot as plt
import pandas as pd 

def dummy_fun(doc):
    return doc

vectorizer = TfidfVectorizer(
    analyzer='word',
    tokenizer=dummy_fun,
    preprocessor=dummy_fun,
    sublinear_tf=True,
    ngram_range=(1,3),
    token_pattern=None)  

tfidf_matrix = vectorizer.fit_transform(files)
feature_names = vectorizer.get_feature_names()
df = pd.DataFrame(tfidf_matrix.todense().tolist(),columns=feature_names)

# %%
print(f"{len(df.columns)} words, {len(df)} rows.")
# Out:
# 172317 words, 175 rows.

# %%
top_words = []
for index in range(0,len(df)):
    values = df.loc[index]
    vals = values[values > 0].sort_values(ascending=False)
    top_words.append(vals[:5])

for index in range(0,len(top_words)):
    print(top_words[index])
    print("--------------")
# Out:
# barrier free workplace    0.081406
# both employees            0.081406
# will attempt              0.081406
# will attempt to           0.081406
# such accommodation        0.081406
# Name: 0, dtype: float64
# --------------
# the certificate                     0.058727
# a certificate                       0.054268
# satisfy certificate                 0.053669
# satisfy certificate requirements    0.053669
# of completion                       0.050274
# Name: 1, dtype: float64
# --------------
# encryption is             0.053372
# encryption                0.050174
# transmitting over         0.048808
# when transmitting         0.048808
# when transmitting over    0.048808
# Name: 2, dtype: float64
# --------------
# water                 0.110582
# single use            0.104797
# single use bottled    0.101453
# use bottled water     0.101453
# use bottled           0.101453
# Name: 3, dtype: float64
# --------------
# 1966/03/24               0.155013
# the language or          0.155013
# language or              0.155013
# language or languages    0.155013
# languages                0.155013
# Name: 4, dtype: float64
# --------------
# hospitality              0.052666
# functions                0.049321
# receptions               0.049286
# reimbursement will       0.049286
# reimbursement will be    0.049286
# Name: 5, dtype: float64
# --------------
# relief             0.092953
# course relief      0.091133
# relief policy      0.091133
# new program        0.091133
# the new program    0.083912
# Name: 6, dtype: float64
# --------------
# bridging program     0.061383
# bridging             0.060595
# bridging programs    0.060196
# academic credits     0.054161
# 4.3.1                0.052472
# Name: 7, dtype: float64
# --------------
# for each major       0.096339
# each major           0.096339
# each major course    0.096339
# major course         0.096339
# preclude setting     0.096339
# Name: 8, dtype: float64
# --------------
# postdoctoral                0.088329
# appointees                  0.074114
# postdoctoral researchers    0.074114
# the fellowship shall        0.068241
# the fellowship              0.068241
# Name: 9, dtype: float64
# --------------
# all expense               0.103568
# expense                   0.098092
# effect from time          0.090238
# in effect from            0.090238
# expense reimbursements    0.083558
# Name: 10, dtype: float64
# --------------
# workplace harassment    0.088139
# workplace               0.084299
# harassment              0.077297
# re approved by          0.074889
# re approved             0.074889
# Name: 11, dtype: float64
# --------------
# merchant    0.047833
# pci         0.047833
# •           0.045566
# pci dss     0.045363
# dss         0.043895
# Name: 12, dtype: float64
# --------------
# the bsw             0.058736
# social work         0.057204
# the school          0.056725
# behaviour review    0.056181
# bsw                 0.054536
# Name: 13, dtype: float64
# --------------
# course rubric             0.123660
# rubric                    0.114506
# rubrics                   0.087438
# course rubrics            0.082863
# proposed course rubric    0.081090
# Name: 14, dtype: float64
# --------------
# essay                  0.070298
# the general counsel    0.067894
# commercial essay       0.067894
# shall undertake        0.062868
# such services          0.062868
# Name: 15, dtype: float64
# --------------
# partnerships             0.086625
# partnerships shall       0.085470
# partnerships shall be    0.079888
# academic freedom         0.063812
# of academic freedom      0.051836
# Name: 16, dtype: float64
# --------------
# license                  0.084948
# license holders          0.076095
# holders                  0.063365
# served                   0.060978
# license holders shall    0.060959
# Name: 17, dtype: float64
# --------------
# a disability          0.064469
# with a disability     0.064469
# person with a         0.064469
# disability            0.059691
# provision of goods    0.058997
# Name: 18, dtype: float64
# --------------
# workplace violence    0.099358
# workplace             0.093094
# violence              0.090477
# physical force        0.085000
# injury to             0.085000
# Name: 19, dtype: float64
# --------------
# ’s insurance               0.101807
# university ’s insurance    0.101807
# insurance program          0.101807
# insurance                  0.100000
# coverage                   0.088924
# Name: 20, dtype: float64
# --------------
# criteria and procedures    0.142275
# policy criteria            0.142275
# criteria and               0.142275
# policy criteria and        0.142275
# 2007                       0.134205
# Name: 21, dtype: float64
# --------------
# of alcohol on    0.104689
# alcohol on       0.104689
# and the terms    0.096939
# of alcohol       0.096939
# alcohol          0.087176
# Name: 22, dtype: float64
# --------------
# co registration           0.087139
# registration option       0.079611
# registration              0.070403
# partner                   0.069021
# co registration option    0.069021
# Name: 23, dtype: float64
# --------------
# a disruption                  0.070866
# executive committee shall     0.061782
# senate executive committee    0.061643
# disruption                    0.061495
# the senate executive          0.059461
# Name: 24, dtype: float64
# --------------
# selection advisory              0.072075
# selection advisory committee    0.072075
# vice chair                      0.066740
# shall elect                     0.065912
# the selection advisory          0.065912
# Name: 25, dtype: float64
# --------------
# correspondence courses    0.100246
# advanced standing         0.094560
# standing and              0.087344
# advanced standing and     0.087344
# 1982/12/16                0.087344
# Name: 26, dtype: float64
# --------------
# of academic honesty    0.038838
# breach of academic     0.035749
# charge                 0.034947
# academic honesty       0.033512
# the charge             0.032963
# Name: 27, dtype: float64
# --------------
# procurement services    0.080185
# surplus                 0.078182
# items                   0.074871
# asset                   0.073879
# of surplus              0.069030
# Name: 28, dtype: float64
# --------------
# de violence             0.037019
# de violence sexuelle    0.036945
# sexuelle                0.035038
# violence sexuelle       0.033890
# de                      0.033121
# Name: 29, dtype: float64
# --------------
# information and data             0.107640
# and data                         0.092045
# institutional information and    0.091774
# institutional information        0.091774
# data resources                   0.079962
# Name: 30, dtype: float64
# --------------
# de       0.080656
# cours    0.077037
# le       0.076513
# la       0.076200
# à        0.073775
# Name: 31, dtype: float64
# --------------
# dohs                    0.052044
# term accommodation      0.049606
# the accommodation       0.047110
# of the accommodation    0.046676
# essential duties        0.045934
# Name: 32, dtype: float64
# --------------
# the search              0.119974
# search committee        0.111145
# the search committee    0.111145
# search                  0.110895
# candidates the          0.080308
# Name: 33, dtype: float64
# --------------
# office or centre                 0.060071
# or centre                        0.055624
# appropriate university office    0.053210
# accommodations                   0.052985
# disability                       0.052119
# Name: 34, dtype: float64
# --------------
# business or program    0.091308
# csbo                   0.086530
# if the applicant       0.079876
# avp csbo               0.079876
# applicant is           0.079876
# Name: 35, dtype: float64
# --------------
# acceptability            0.101274
# of research funds        0.087159
# acceptability of         0.086565
# on research              0.086565
# committee on research    0.086565
# Name: 36, dtype: float64
# --------------
# a healthy workplace    0.079614
# a healthy              0.079614
# healthy                0.078620
# healthy workplace      0.078620
# re approved by         0.065900
# Name: 37, dtype: float64
# --------------
# feedback         0.076929
# drop date        0.074534
# the drop date    0.074534
# 1994/01/27       0.074534
# the drop         0.074534
# Name: 38, dtype: float64
# --------------
# theft                           0.074245
# fraud                           0.073786
# agents contractors              0.071243
# employees agents                0.071243
# employees agents contractors    0.071243
# Name: 39, dtype: float64
# --------------
# risks                  0.102254
# risk management        0.095727
# risk                   0.091643
# emerging risks         0.075273
# institutional risks    0.075273
# Name: 40, dtype: float64
# --------------
# the transfer student    0.081054
# transfer student        0.081054
# given the               0.075276
# in canada               0.070797
# the need to             0.070797
# Name: 41, dtype: float64
# --------------
# perturbation       0.065136
# les                0.057954
# la perturbation    0.056266
# de                 0.055415
# et                 0.055368
# Name: 42, dtype: float64
# --------------
# food truck       0.095911
# truck            0.088811
# food             0.084064
# the food         0.072627
# food services    0.071116
# Name: 43, dtype: float64
# --------------
# the common         0.096452
# m                  0.082514
# the master plan    0.082514
# common shall       0.082514
# adjoining          0.082514
# Name: 44, dtype: float64
# --------------
# chief invigilator          0.075770
# invigilator                0.074247
# the chief invigilator      0.074069
# chief invigilator shall    0.065451
# the examination            0.063094
# Name: 45, dtype: float64
# --------------
# university events    0.061014
# events               0.060764
# public figures       0.059115
# visits to            0.059115
# figures              0.059115
# Name: 46, dtype: float64
# --------------
# orus                  0.061677
# charters              0.055915
# oru                   0.052263
# organized research    0.048273
# charters are          0.045392
# Name: 47, dtype: float64
# --------------
# work the        0.103234
# the work        0.102151
# art             0.094685
# art work        0.092837
# the work the    0.089947
# Name: 48, dtype: float64
# --------------
# incurred                    0.108108
# hospitality expenditures    0.104714
# hospitality                 0.104370
# incurred in                 0.090403
# 2012                        0.088604
# Name: 49, dtype: float64
# --------------
# pets              0.103685
# pet               0.103685
# pets on campus    0.090535
# pets on           0.090535
# animals           0.083445
# Name: 50, dtype: float64
# --------------
# weapon                     0.090698
# firearms                   0.083984
# ammunition                 0.073859
# ammunition or explosive    0.073859
# ammunition or              0.073859
# Name: 51, dtype: float64
# --------------
# existing facilities    0.103731
# 1994/05/26             0.089554
# persons with           0.087772
# disabilities           0.083150
# ensuring that          0.073741
# Name: 52, dtype: float64
# --------------
# weather emergency      0.054492
# vpfa                   0.053835
# the dss                0.049440
# a weather emergency    0.049029
# a weather              0.046248
# Name: 53, dtype: float64
# --------------
# university parking         0.113751
# parking                    0.106858
# traffic regulations        0.091773
# university parking and     0.091773
# york university parking    0.091773
# Name: 54, dtype: float64
# --------------
# compulsory              0.084307
# ancillary fees          0.082736
# compulsory ancillary    0.075237
# ancillary fee           0.071300
# increase                0.070236
# Name: 55, dtype: float64
# --------------
# message               0.078627
# electronic message    0.076279
# an electronic         0.076279
# installed             0.076279
# computer program      0.069756
# Name: 56, dtype: float64
# --------------
# information technology facilities    0.160230
# technology facilities                0.160230
# computing and information            0.160230
# and information technology           0.156750
# computing and                        0.153529
# Name: 57, dtype: float64
# --------------
# or postponement                 0.085396
# cancellation or postponement    0.085396
# postponement                    0.085396
# cancellation or                 0.085396
# cancellation                    0.085035
# Name: 58, dtype: float64
# --------------
# the vehicle      0.084163
# turf             0.082400
# vehicle          0.080224
# walkway          0.077019
# vehicle shall    0.070433
# Name: 59, dtype: float64
# --------------
# l’honnêteté                   0.040305
# l’honnêteté intellectuelle    0.040088
# à                             0.039487
# de                            0.038014
# la                            0.036877
# Name: 60, dtype: float64
# --------------
# brand properties     0.101134
# properties           0.101134
# brand                0.087505
# brand property       0.086446
# distinctive image    0.082102
# Name: 61, dtype: float64
# --------------
# a final examination    0.109477
# final                  0.098561
# final examination      0.098451
# pass                   0.085763
# a final                0.079554
# Name: 62, dtype: float64
# --------------
# such courses               0.072160
# integrated                 0.070056
# more stringent             0.064303
# stringent                  0.064303
# individual programs may    0.064303
# Name: 63, dtype: float64
# --------------
# network                      0.06283
# central computing            0.05911
# the university network       0.05911
# central computing support    0.05911
# computing support group      0.05911
# Name: 64, dtype: float64
# --------------
# the act                 0.064774
# personal information    0.062354
# to the act              0.057092
# to records              0.052210
# information relating    0.049867
# Name: 65, dtype: float64
# --------------
# the employees of      0.122818
# the faculty member    0.122790
# faculty member        0.115966
# the employees         0.110448
# employee of           0.102300
# Name: 66, dtype: float64
# --------------
# 1969/04/24            0.075705
# these programmes      0.075705
# accountants           0.075705
# division concerned    0.075705
# accountants the       0.075705
# Name: 67, dtype: float64
# --------------
# standing credit              0.086993
# advanced standing credit     0.086993
# advanced standing            0.085184
# advanced                     0.070745
# universities and colleges    0.070468
# Name: 68, dtype: float64
# --------------
# business or program      0.119109
# the business or          0.104648
# or program               0.099211
# business or              0.093309
# program on university    0.092237
# Name: 69, dtype: float64
# --------------
# nouveau programme    0.091266
# de                   0.087947
# nouveau              0.084510
# cours                0.083332
# les                  0.083332
# Name: 70, dtype: float64
# --------------
# awards               0.069958
# scholarships         0.066817
# appear on a          0.063916
# committees will      0.058451
# academic criteria    0.058451
# Name: 71, dtype: float64
# --------------
# employment equity       0.082571
# equity                  0.077361
# of employment equity    0.075184
# equity in               0.066120
# employment              0.060539
# Name: 72, dtype: float64
# --------------
# grades of         0.084768
# with grades       0.077519
# ib                0.077519
# with grades of    0.077519
# advanced          0.075342
# Name: 73, dtype: float64
# --------------
# e mail              0.065830
# mail                0.064401
# mail resources      0.059581
# e                   0.058017
# e mail resources    0.056997
# Name: 74, dtype: float64
# --------------
# granting of tenure         0.118199
# of tenure                  0.118199
# of tenure and              0.118199
# appointment granting       0.118199
# appointment granting of    0.118199
# Name: 75, dtype: float64
# --------------
# of special events    0.081664
# office of special    0.078774
# lecture              0.073743
# of special           0.068003
# lecture series       0.051656
# Name: 76, dtype: float64
# --------------
# course or courses    0.111731
# summer               0.102262
# or courses           0.102262
# course or            0.090332
# the student          0.086622
# Name: 77, dtype: float64
# --------------
# access control program        0.105410
# control program               0.105410
# to university buildings       0.105410
# interior                      0.097607
# procedures and regulations    0.097607
# Name: 78, dtype: float64
# --------------
# the design of    0.111546
# architects       0.106343
# design of        0.106343
# the design       0.102092
# design           0.096327
# Name: 79, dtype: float64
# --------------
# techniques              0.123249
# assignment or course    0.114922
# and/or techniques       0.114922
# an assignment or        0.114922
# concepts and/or         0.114922
# Name: 80, dtype: float64
# --------------
# orus                 0.066671
# oru                  0.066057
# charter              0.059069
# on orus              0.054565
# the sub committee    0.054062
# Name: 81, dtype: float64
# --------------
# of fraud theft       0.080468
# of fraud             0.080468
# evidence of fraud    0.073587
# fraud                0.070066
# fraud theft          0.068823
# Name: 82, dtype: float64
# --------------
# or hospitality         0.077408
# gift or hospitality    0.070666
# gifts or               0.065435
# gift                   0.062866
# manager or             0.062595
# Name: 83, dtype: float64
# --------------
# human participants              0.127114
# research involving human        0.127114
# involving human participants    0.127114
# involving human                 0.127114
# research involving              0.119904
# Name: 84, dtype: float64
# --------------
# bridging course           0.087370
# bridging                  0.083369
# university preparation    0.081664
# a bridging course         0.081664
# a bridging                0.081664
# Name: 85, dtype: float64
# --------------
# weapons             0.123187
# firearms            0.112653
# substances          0.106263
# ammunition          0.099072
# firearms weapons    0.099072
# Name: 86, dtype: float64
# --------------
# disability           0.080276
# “ disability         0.071535
# “ disability ”       0.071535
# disability ”         0.071535
# accessibility for    0.068604
# Name: 87, dtype: float64
# --------------
# length from                 0.0558
# entity in                   0.0558
# no university employee      0.0558
# no university               0.0558
# interest either directly    0.0558
# Name: 88, dtype: float64
# --------------
# names of all           0.088558
# determine the names    0.088558
# the names of           0.084660
# to honour              0.082003
# names of               0.081984
# Name: 89, dtype: float64
# --------------
# student rights and             0.141003
# of student rights              0.141003
# marsden                        0.141003
# rights and responsibilities    0.141003
# student rights                 0.141003
# Name: 90, dtype: float64
# --------------
# advisory committee                 0.126607
# on recognition                     0.126607
# presidential advisory              0.116945
# presidential advisory committee    0.116945
# advisory                           0.102359
# Name: 91, dtype: float64
# --------------
# incapacitation              0.102826
# death                       0.095214
# permanent incapacitation    0.091082
# aegrotat standing           0.091082
# aegrotat                    0.091082
# Name: 92, dtype: float64
# --------------
# renovation and                0.104846
# of construction renovation    0.104846
# renovation and alterations    0.104846
# awarding of construction      0.104846
# and alterations               0.104846
# Name: 93, dtype: float64
# --------------
# student government             0.048383
# constitution                   0.043305
# student relations committee    0.042449
# student relations              0.042449
# relations committee            0.042449
# Name: 94, dtype: float64
# --------------
# a right                    0.086264
# 1995/06/26                 0.086264
# human rights               0.076009
# by the ontario             0.074475
# york university affirms    0.074475
# Name: 95, dtype: float64
# --------------
# payroll                0.068902
# with its policy        0.066757
# pension plan           0.066757
# its policy and         0.066757
# accordance with its    0.066757
# Name: 96, dtype: float64
# --------------
# academic activities          0.067614
# academic response            0.066900
# where academic activities    0.066900
# disruption                   0.062130
# a disruption                 0.061947
# Name: 97, dtype: float64
# --------------
# the campaign        0.114329
# campaign            0.111954
# will be credited    0.093934
# be credited         0.091784
# campaign period     0.087800
# Name: 98, dtype: float64
# --------------
# certifications    0.103407
# certified         0.083164
# workers           0.078767
# work group        0.072460
# group or unit     0.072460
# Name: 99, dtype: float64
# --------------
# the final    0.099836
# classes      0.097885
# worth        0.090625
# a term       0.084063
# final        0.078290
# Name: 100, dtype: float64
# --------------
# 1985/01/24              0.130381
# free language           0.130381
# gendered language       0.130381
# gender free language    0.130381
# gender free             0.130381
# Name: 101, dtype: float64
# --------------
# into on            0.087293
# entered into on    0.087293
# into on behalf     0.087293
# entered            0.078501
# entered into       0.078501
# Name: 102, dtype: float64
# --------------
# propaganda             0.110521
# hate propaganda        0.110521
# hate                   0.104252
# hate propaganda may    0.068832
# propaganda may         0.068832
# Name: 103, dtype: float64
# --------------
# hprc               0.041863
# the hprc           0.039803
# ethics review      0.037471
# research ethics    0.036392
# reb                0.033608
# Name: 104, dtype: float64
# --------------
# accommodations shall          0.072043
# accommodations shall be       0.072043
# accommodations                0.070133
# students with disabilities    0.065938
# students with                 0.063692
# Name: 105, dtype: float64
# --------------
# surplus             0.126464
# declared surplus    0.114540
# architects          0.103004
# declared            0.103004
# 2007/06/25          0.098887
# Name: 106, dtype: float64
# --------------
# perquisites       0.105523
# clubs             0.074824
# summary list      0.069114
# not related to    0.069114
# perquisite        0.069114
# Name: 107, dtype: float64
# --------------
# social media         0.093870
# media                0.077643
# images               0.073307
# social               0.064614
# practice standard    0.064469
# Name: 108, dtype: float64
# --------------
# transit        0.079814
# vehicle        0.076279
# idling         0.074089
# the vehicle    0.073906
# city           0.073540
# Name: 109, dtype: float64
# --------------
# professor                           0.078370
# distinguished research professor    0.075124
# research professor                  0.075124
# distinguished research              0.075089
# university professor                0.072727
# Name: 110, dtype: float64
# --------------
# normally headed       0.062961
# normally headed by    0.062961
# headed by             0.058300
# headed                0.058300
# headed by a           0.055250
# Name: 111, dtype: float64
# --------------
# without authorization         0.071694
# data without                  0.067012
# data without authorization    0.067012
# computing and information     0.065033
# and information technology    0.063620
# Name: 112, dtype: float64
# --------------
# ontario universities       0.112986
# for credit by              0.104363
# 1993/12/09                 0.104363
# acceptance of transfer     0.104363
# of ontario universities    0.096638
# Name: 113, dtype: float64
# --------------
# 1995/05/25                       0.128021
# scarsa                           0.102343
# institutions                     0.078001
# effective 1995/05/25 approval    0.075611
# if an educational                0.075611
# Name: 114, dtype: float64
# --------------
# the account        0.068861
# passwords          0.067065
# account holders    0.066324
# accounts           0.064762
# system accounts    0.063448
# Name: 115, dtype: float64
# --------------
# remembrance             0.134301
# remembrance day         0.134301
# women                   0.132787
# women ’s remembrance    0.123973
# ’s remembrance          0.123973
# Name: 116, dtype: float64
# --------------
# information resource         0.063431
# igc                          0.058195
# institutional information    0.057269
# steward                      0.057269
# the information              0.056991
# Name: 117, dtype: float64
# --------------
# incumbent president        0.116704
# incumbent                  0.097181
# the incumbent president    0.093858
# senate will                0.093858
# of senate will             0.093858
# Name: 118, dtype: float64
# --------------
# honorary              0.115217
# honorary governors    0.105510
# honorary governor     0.096554
# governor              0.086019
# term on the           0.077653
# Name: 119, dtype: float64
# --------------
# visiting students                    0.066213
# language proficiency requirements    0.063084
# language proficiency                 0.063084
# proficiency requirements             0.063084
# visiting                             0.062065
# Name: 120, dtype: float64
# --------------
# debts                       0.148738
# debts to                    0.120001
# debts to the                0.120001
# emergencies policy final    0.081143
# grade reports and           0.081143
# Name: 121, dtype: float64
# --------------
# poster       0.071610
# posters      0.069158
# signs        0.058445
# notices      0.054944
# postering    0.052747
# Name: 122, dtype: float64
# --------------
# of the chief                  0.100069
# communications officer        0.092661
# the chief marketing           0.092661
# chief marketing               0.092661
# and communications officer    0.091512
# Name: 123, dtype: float64
# --------------
# conflict of             0.059858
# conflict of interest    0.059858
# conflict                0.058588
# related persons         0.055986
# which the faculty       0.054072
# Name: 124, dtype: float64
# --------------
# employed by the         0.099478
# employed by             0.092114
# under a                 0.092114
# grants and contracts    0.090427
# and contracts           0.090427
# Name: 125, dtype: float64
# --------------
# cgpa                 0.128309
# september 25 2014    0.111795
# 25 2014              0.111795
# 2014                 0.103519
# september 25         0.103519
# Name: 126, dtype: float64
# --------------
# banners         0.095082
# the banners     0.082431
# the proposal    0.079789
# banner          0.072335
# proposal        0.069022
# Name: 127, dtype: float64
# --------------
# course credit               0.063940
# credit exclusions           0.058989
# course credit exclusions    0.058989
# course descriptions         0.052920
# descriptions                0.051827
# Name: 128, dtype: float64
# --------------
# preparedness                      0.125976
# emergency preparedness            0.125976
# preparedness program              0.109311
# emergency preparedness program    0.109311
# office of emergency               0.109311
# Name: 129, dtype: float64
# --------------
# ecommerce                   0.090604
# treasury                    0.068994
# cns                         0.064332
# cns information             0.062411
# cns information security    0.062411
# Name: 130, dtype: float64
# --------------
# scotl                 0.079504
# feedback              0.071852
# one occasion          0.056637
# least one occasion    0.056637
# department-           0.056637
# Name: 131, dtype: float64
# --------------
# delegation                 0.07688
# signing register           0.07688
# in the signing             0.07688
# delegation of              0.07688
# delegation of authority    0.07688
# Name: 132, dtype: float64
# --------------
# governor         0.090112
# a governor       0.084771
# fiduciary        0.063704
# a governor ’s    0.058989
# governor ’s      0.058989
# Name: 133, dtype: float64
# --------------
# shall mean        0.096055
# mean              0.076789
# of the project    0.073785
# projects          0.071037
# or undertake      0.068154
# Name: 134, dtype: float64
# --------------
# code of ethics         0.086717
# of ethics              0.083976
# suppliers              0.082195
# ethics                 0.077439
# procurement code of    0.075296
# Name: 135, dtype: float64
# --------------
# la       0.064958
# le       0.064250
# cours    0.063883
# de       0.063155
# les      0.058846
# Name: 136, dtype: float64
# --------------
# claims                 0.045174
# travel                 0.045174
# claimant               0.044268
# the claimant           0.042559
# accountable advance    0.041604
# Name: 137, dtype: float64
# --------------
# weather emergency               0.117305
# emergency procedures            0.112213
# weather emergency procedures    0.102617
# weather                         0.100641
# emergency                       0.083711
# Name: 138, dtype: float64
# --------------
# records                    0.069879
# records and information    0.069003
# records and                0.066389
# information relating       0.065089
# information relating to    0.065089
# Name: 139, dtype: float64
# --------------
# the difficulty is     0.10101
# the difficulty        0.10101
# is such that          0.10101
# difficulty is         0.10101
# difficulty is such    0.10101
# Name: 140, dtype: float64
# --------------
# misconduct           0.048385
# of misconduct        0.045981
# graphs and           0.042078
# graphs               0.042078
# graphs and images    0.042078
# Name: 141, dtype: float64
# --------------
# architects                  0.114344
# services can                0.097429
# and landscape architects    0.097429
# and landscape               0.097429
# such services can           0.097429
# Name: 142, dtype: float64
# --------------
# copying         0.129079
# fair dealing    0.118041
# dealing         0.104233
# library         0.103810
# “ fair          0.095888
# Name: 143, dtype: float64
# --------------
# an ungraded basis    0.093671
# ungraded basis       0.093671
# on an ungraded       0.093671
# an ungraded          0.093671
# ungraded             0.086737
# Name: 144, dtype: float64
# --------------
# repeat                   0.080721
# the grade                0.076143
# degree or                0.067236
# degree or certificate    0.066963
# the student ’s           0.063236
# Name: 145, dtype: float64
# --------------
# the conflict       0.077077
# conflict           0.072392
# employee or        0.070485
# of the conflict    0.067728
# an employee        0.066407
# Name: 146, dtype: float64
# --------------
# cgpa                 0.130680
# cgpa requirements    0.114925
# honours              0.080020
# year                 0.077100
# impact major         0.059140
# Name: 147, dtype: float64
# --------------
# chairs                0.070318
# designations          0.065701
# chairs and            0.062753
# distinguished         0.061503
# and professorships    0.060838
# Name: 148, dtype: float64
# --------------
# the common               0.122037
# university common        0.112575
# common                   0.100249
# university common has    0.096286
# common has               0.096286
# Name: 149, dtype: float64
# --------------
# affirmative action        0.131086
# affirmative               0.123650
# the affirmative action    0.113852
# the affirmative           0.113852
# goals established by      0.091855
# Name: 150, dtype: float64
# --------------
# of religious                 0.075234
# religious significance       0.069023
# of religious significance    0.069023
# religious                    0.062730
# dates of                     0.060270
# Name: 151, dtype: float64
# --------------
# merger                     0.116468
# endowment funds            0.116468
# the funds                  0.110280
# university 's endowment    0.093966
# funds were                 0.093966
# Name: 152, dtype: float64
# --------------
# grades for        0.118510
# each component    0.109466
# component         0.104647
# the course the    0.101362
# course the        0.091153
# Name: 153, dtype: float64
# --------------
# student shall be     0.089529
# the student shall    0.082901
# student 's           0.081383
# student shall        0.078199
# registered           0.076036
# Name: 154, dtype: float64
# --------------
# sororities                     0.115488
# fraternities                   0.115488
# and sororities                 0.107946
# fraternities and sororities    0.107946
# fraternities and               0.107946
# Name: 155, dtype: float64
# --------------
# vendors              0.053610
# vendors of           0.051793
# with vendors         0.048841
# goods and/or         0.048841
# vendors of record    0.047722
# Name: 156, dtype: float64
# --------------
# related persons         0.065663
# conflict of             0.064769
# conflict of interest    0.064769
# conflict                0.064094
# financial interest      0.060048
# Name: 157, dtype: float64
# --------------
# course credits    0.128613
# least half 50     0.118798
# percent           0.118798
# percent of the    0.118798
# least half        0.118798
# Name: 158, dtype: float64
# --------------
# and/or dean or                          0.091966
# chair and/or dean                       0.091966
# appropriate alternative arrangements    0.091966
# alternative arrangements                0.091966
# alternative arrangements for            0.091966
# Name: 159, dtype: float64
# --------------
# graduate diploma        0.104987
# the graduate diploma    0.088755
# diploma                 0.080190
# master 's               0.076632
# diploma is              0.075027
# Name: 160, dtype: float64
# --------------
# examination schedules    0.058626
# holiday of               0.057898
# examinations will        0.057898
# be scheduled             0.057898
# holiday                  0.057898
# Name: 161, dtype: float64
# --------------
# cash                    0.125744
# and cash                0.101846
# and cash equivalents    0.101846
# cash and                0.101846
# cash and cash           0.101846
# Name: 162, dtype: float64
# --------------
# or creative               0.042872
# outside the university    0.041891
# discharged                0.040073
# creative                  0.037672
# of outside                0.037447
# Name: 163, dtype: float64
# --------------
# the provost              0.055190
# and teaching             0.047647
# research and teaching    0.045414
# establishment of a       0.045132
# professorship            0.043348
# Name: 164, dtype: float64
# --------------
# the school          0.067618
# schools             0.063202
# proposals should    0.061041
# equivalent to a     0.061041
# school is           0.061041
# Name: 165, dtype: float64
# --------------
# sustainability           0.079827
# talloires                0.071503
# york will                0.068295
# talloires declaration    0.062883
# sustainable              0.062455
# Name: 166, dtype: float64
# --------------
# accepting payment            0.137180
# payment card                 0.118433
# accepting                    0.114263
# accepting payment card       0.110326
# payment card transactions    0.110326
# Name: 167, dtype: float64
# --------------
# sexual violence response    0.039298
# violence response           0.039298
# the sexual violence         0.039298
# sexual violence             0.038004
# response office             0.036421
# Name: 168, dtype: float64
# --------------
# gift          0.062860
# securities    0.060704
# charitable    0.054148
# gifts         0.053984
# donors        0.052008
# Name: 169, dtype: float64
# --------------
# the school                       0.058083
# breach of professional           0.055829
# nursing                          0.055761
# behaviour review                 0.055691
# professional behaviour review    0.055691
# Name: 170, dtype: float64
# --------------
# quality council        0.061654
# the quality council    0.057339
# joint sub committee    0.056052
# the joint sub          0.056052
# joint sub              0.056052
# Name: 171, dtype: float64
# --------------
# withdrawn from course    0.069816
# from course              0.066559
# withdrawn from           0.063899
# withdrawal deadline      0.063155
# hardship                 0.062062
# Name: 172, dtype: float64
# --------------
# phone 416    0.067384
# damages      0.067384
# 416          0.065664
# 416 487      0.063998
# 487          0.063998
# Name: 173, dtype: float64
# --------------
# mpf                0.096205
# project            0.067384
# master planning    0.066704
# mpf shall          0.065877
# projects           0.060815
# Name: 174, dtype: float64
# --------------

# %%
# print(paths["yale"])
# generate_tags_template(paths["stanford"])

# %%
print(get_all_tags(data_dir))
# Out:
# Found 3 files in 10 directories.
# ['students', 'degree requirements', 'student accounts', 'salary', 'conflict of interest', 'unversity buildings', 'vehicles', 'weather', 'finances', 'smoking', 'hiring', 'performance management', 'substances', 'academic nomenclature', 'art', 'credit', 'time off', 'workplace relationships', 'charity', 'media', 'medical accomodation', 'cross listing courses', 'information technology', 'snow', 'information security', 'firearms', 'email', 'racism', 'governance', 'computer technology', 'sororities', 'course relief', 'alcohol', 'water', 'employee training', 'branding', 'IT', 'liability', 'sexual violence', 'president', 'minors', 'social justice', 'sustainability', 'heatlh', 'code of ethics', 'hate speech', 'essay writing', 'academic integrity', 'theft', 'postdoc', 'university commons', 'expenses', 'university government', 'mail', 'recruiting', 'students with religious requirements', 'naming', 'advanced credit', 'unversity finances', 'promotions', 'academic accomodation', 'university property', 'code of conduct', 'grading scheme', 'fraud', 'internet access', 'compensation', 'copmensation', 'reporting requirements', 'affirmative action', 'disability', 'student government', 'facilities', 'copyright', 'harmassment', 'researcH', 'equipment', 'founding schools', 'research policy', 'procurement', 'requistions', 'purchases', 'risk management', 'expense policy', 'sexual misconduct', 'conferences', 'security', 'ethics', 'employment', 'grades', 'graduate students', 'registration', 'research code of conduct', 'construction', 'course credit', 'students with disabilities', 'accounts receivable', 'presidential term', 'infosec', 'use of university property', 'policy changes', 'research chair', 'social media policy', 'fundraising', 'women', 'university finances', 'equality', 'telecommuting', 'gift policy', 'workplace harmassment', 'antirequisite', 'software', 'public relations', 'graduate studies', 'course requirements', 'auditing', 'sick leave', 'program review', 'crime', 'honorary professorship', 'shipping', 'degree granting', 'examinations', 'workplace harassment', 'internet', 'information management', 'sexual harassment', 'administration', 'traffic', 'tenure', 'businesses', 'cash', 'Sustainability', 'grading rubric', 'coursework', 'animals', 'equal opportunity', 'ancillary fees', 'building security', 'capital projects', 'guns', 'advertising', 'research eligibility', 'course cancellations', 'benefits', 'wellness', 'academic honesty', 'partnerships', 'anti-discrimination', 'french', 'events', 'research ethics', 'data', 'academic calendar', 'capital expenses', 'student affairs', 'drugs', 'academic sanctions', 'environment', 'credits', 'research', 'courses', 'VIP', 'development', 'interdisciplinary', 'purchasing', 'assets', 'intellectual property', 'awards', 'web', 'social media', 'certification', 'scholarship', 'remote work', 'signing authority', 'equity', 'accommodation for persons with disabilities', 'eximations', 'free speech', 'post doctoral research', 'capex', 'plagiarism', 'endowment funds', 'politics', 'spam', 'operations', 'food', 'real estate', 'religious accomodation', 'grading', 'fraternities', 'organization', 'board of directors', 'emergencies', 'teaching chair', 'weapons', 'advanced standing', 'religion', 'ehtics', 'payment', 'visas', 'PTO', 'insurance', 'labour policy', 'teaching evaluation', 'work travel', 'course rubric', 'special events', 'postering', 'compliance', 'student rights and responsiblities', 'workplace violence', 'bridging courses', 'banking', 'dining', 'first aid', 'safety', 'immigration', 'privacy', 'professional conduct', 'consulting', 'employees', 'grading policy', 'training', 'protesting', 'faculty responsiblities', 'gifts', 'faculty', 'banners', 'pets', 'academic standing', 'harassment', 'business', 'tuition reimbursement', 'breastfeeding', 'health & safety', 'calendar', 'parental accomodation', 'relationships', 'employment equity', 'accounting', 'leave', 'housing', 'technology', 'disabilities', 'term renewal', 'und ...
