# %% [markdown]
# Below, we take of downloading the files, extracting them and reading the first file into memory. Note that unless `overwrite` is set, the files are not re-downloaded or re-extracted.

# %%
import urllib.request
import os

base_url = "http://knowitall.cs.washington.edu/oqa/data/wikianswers/"
number_of_archive_parts = 39
data_directory = os.path.expanduser('~/data/')
overwrite = False

if not os.path.exists(data_directory):
    os.makedirs(data_directory)

# Create list of files to fetch
parts = [
    f"part-{str(part_num).zfill(5)}.gz"
    for part_num in range(0, number_of_archive_parts)
]
questions = "questions.txt"
files = parts + [questions]

print(f"Requesting {len(files)} data files.")
if (overwrite == False):
    files = list(filter(lambda file: not os.path.exists(data_directory + file), files))
    print(f"Downloading {len(files)} files.")

# Fetch WikiAnswer paraphrase corpus
urls = [base_url + file for file in files]
results = [
    urllib.request.urlretrieve(url, data_directory + filename)
    for (url, filename) in zip(urls, files)
]
print("Done.")
# Out:
# Requesting 40 data files.
# Downloading 0 files.
# Done.

# %%
import gzip
import shutil

def extract_files(files_to_extract):
    # Check for previously extracted files and skip them if not overwriting
    extracted_file_names = [os.path.splitext(file)[0] for file in files_to_extract]
    if (overwrite == False):
        files_to_extract = list(filter(lambda file: not os.path.exists(data_directory + file), extracted_file_names))
        print(f"Extracting {len(files_to_extract)} files.")

    for file in files_to_extract:
        with gzip.open(data_directory + file + ".gz", 'rb') as f_in:
            with open(data_directory + file, 'wb') as f_out:
                shutil.copyfileobj(f_in, f_out)
    return extracted_file_names
extracted_files = extract_files(parts)
# Out:
# Extracting 0 files.

# %%
import re

def process_line(line):
    return [re.sub('q:','', question) for question in line.split('\t') if question.find('a:') == -1]

file = data_directory + extracted_files[-1]
print(file)
with open(file) as f:
    lines = [process_line(line) for line in f.readlines()]
# Out:
# /Users/erikbeerepoot/data/part-00038

# %% [markdown]
# We use Glove word embeddings: [GloVE](https://nlp.stanford.edu/projects/glove/). GloVe is a great alternative to Word2Vec and often yields slightly better results. In this case, we're using the set that was trained on a smaller corpus.

# %%
import csv
import pandas as pd

# Read in GloVe word embeddings
embeddings_50d = "../../word_embeddings/glove.6B/glove.6B.100d.text"
embeddings_100d = "../../word_embeddings/glove.6B/glove.6B.100d.text"
embeddings_200d = "../../word_embeddings/glove.6B/glove.6B.200d.text"
embeddings_300d = "../../word_embeddings/glove.6B/glove.6B.300d.txt"

embeddings = pd.read_table(embeddings_300d, delim_whitespace=True, index_col=0, header=None, quoting=csv.QUOTE_NONE)
embedding_dim = 300

# %% [markdown]
# In each of the of the downloaded `.gz` files, there are sets of clustered questions. For example:
#
# ```
# <SNIP>
# q:Calories in a handful of strawberries?	q:Calories in handful of strawberries?	q:How many calories are in 1cup of strawberrys?	q:How many calories are in a handful of strawberries?
# </SNIP>
# ```
#
# While the data are not perfect (some are more similar than others), it overall looks reasonable. We want to:
# 1. Read in each of the clusters, and generate pairs of similar questions
# 2. Randomly sample from other clusters to generate pairs of dissimilar questions
# 3. Train our model on this dataset
#
# In order to maintain a balanced dataset, we want to create as many negative examples as there are postive examples. Hence, we compute the number of permutations (question pairs) we obtain and generate the same number of non-similar pairs.

# %%
import itertools


def generate_question_pairs(cluster):
    """
    Generate permutations of length to (i.e. question pairs) 
    """
    return list(itertools.permutations(cluster, 2))


def generate_uniform_random_indices(low, high, count):
    """
    Returns a list of integers using the discrete uniform distribution, without repeats.
    low -- Starting index
    high -- Ending index
    count -- The number of integers to generate 
    """
    random_integers = []
    generated_count = 0
    while (generated_count < count):
        # Generate a random integer that doesn't match [forbidden]
        random_integer = np.random.randint(0, count)
        while (random_integer in random_integers):
            random_integer = np.random.randint(0, count)
        random_integers.append(random_integer)
        generated_count = generated_count + 1
    return random_integers


def assemble_distinct_question_pairs(current_cluster_index, num_to_generate,
                                     all_clusters):
    """
    Returns a list of dissimilar questions (i.e. negative examples)
    current_cluster_index -- The index of the currrent cluster we're processing
    num_to_generate -- The number of distinct pairs to generate
    all_clusters -- The set of all clusters of questions
    """
    number_of_clusters = len(all_clusters)
    indices = generate_uniform_random_indices(0, number_of_clusters,
                                              num_to_generate)

    questions = [
        all_clusters[index][np.random.randint(0, len(all_clusters[index]))]
        for index in indices
    ]
    return generate_question_pairs(questions)


# Generate distinct question pairs that are semantically similar
similar_question_pairs = []
distinct_question_pairs = []

foo = lines[0:2]
for line in foo:
    number_of_distinct_phrasings = len(line)
    cluster_index = lines.index(line)
    question_pairs = generate_question_pairs(line)

    similar_question_pairs = similar_question_pairs + question_pairs
    distinct_question_pairs = distinct_question_pairs + assemble_distinct_question_pairs(
        cluster_index, number_of_distinct_phrasings, lines
    )

num_similar_question_pairs = sum(
    list([len(foo) for foo in similar_question_pairs]))
num_distinct_question_pairs = sum(
    list([len(foo) for foo in distinct_question_pairs]))
assert (num_similar_question_pairs == num_distinct_question_pairs)

# %% [markdown]
# Now that we have the question pairs, we can assemble them into our input dataframe:

# %%
import pandas as pd

df = pd.DataFrame(
    similar_question_pairs[0:10], columns=['question1', 'question2'])
print(df)
# Out:
# [('2005 jeep Cherokee yellow exclamation light?', '2005 jeep grand cherokee dashboard symbols?'), ('2005 jeep Cherokee yellow exclamation light?', '2007 jeep cherokee exclamation point light in dashboard?'), ('2005 jeep Cherokee yellow exclamation light?', 'Dashboard lights on 2005 jeep grand cherokee?'), ('2005 jeep Cherokee yellow exclamation light?', 'Exclamation point horseshoe?'), ('2005 jeep Cherokee yellow exclamation light?', 'Exclamation point with a crooked line under it on a 2004 jeep laredo mean?'), ('2005 jeep Cherokee yellow exclamation light?', 'How do you change dashboard light on 2005 jeep?'), ('2005 jeep Cherokee yellow exclamation light?', 'Jeep grand cherokee horseshoe?'), ('2005 jeep Cherokee yellow exclamation light?', 'Light on dashboard exclamation point jeep cherokee?'), ('2005 jeep Cherokee yellow exclamation light?', 'On a 2002 ford windstar you have a yellow light on that looks like a horseshoe with an exclamation in it Does anyone know what it is?'), ('2005 jeep Cherokee yellow exclamation light?', 'On a 2005 Jeep Grand Cherokee what does the yellow dashboard light that looks like a horseshoe with a exclamation mark in it?'), ('2005 jeep Cherokee yellow exclamation light?', 'On a 2005 Jeep Grand Cherokee what does the yellow dashboard light that looks like a horseshoe with an exclamation point in the middle mean?'), ('2005 jeep Cherokee yellow exclamation light?', 'What do the Jeep 2005 grand cherokee light symbols look like?'), ('2005 jeep Cherokee yellow exclamation light?', 'What does a exclamation point mean on dashboard of jeep liberty renegade?'), ('2005 jeep Cherokee yellow exclamation light?', 'What does a horseshoe and exclamation point lit up on dash of a 2005 ford expedition mean?'), ('2005 jeep Cherokee yellow exclamation light?', 'What does a horseshoe with an exclaimation point mean in a 2005 jeep cherokee?'), ('2005 jeep Cherokee yellow exclamation light?', 'What does a warning light that is shaped like an upside down horseshoe with an exclaimation point in the middle indicate for an F150 truck?'), ('2005 jeep Cherokee yellow exclamation light?', 'What does an orange in a horseshoe mean on a 2007 jeep commando?'), ('2005 jeep Cherokee yellow exclamation light?', 'What does the dashboard light with an eclamation point inside a horse shoe mean on a jeep commando?'), ('2005 jeep Cherokee yellow exclamation light?', 'What does the exclamation point mean in a jeep loredo?'), ('2005 jeep Cherokee yellow exclamation light?', 'What does the exclamation point with a horseshoe mean on a grand cherokee?'), ('2005 jeep Cherokee yellow exclamation light?', 'What does the exclamation point with horseshoe mean?'), ('2005 jeep Cherokee yellow exclamation light?', 'What does the horseshoe light on jeep cherokee?'), ('2005 jeep Cherokee yellow exclamation light?', 'What does the horseshoe light with an exclamation mark in the middle mean?'), ('2005 jeep Cherokee yellow exclamation light?', 'What does the horseshoe with the exclamation point light mean?'), ('2005 jeep Cherokee yellow exclamation light?', 'What does the parenthesis and exclamation point mean on the dash of a 2005 jeep laredo?'), ('2005 jeep Cherokee yellow exclamation light?', 'What does the yellow horseshoe dashboard light mean in a 2008 ford ranger truck?'), ('2005 jeep Cherokee yellow exclamation light?', 'What does the yellow horseshoe light mean when lit on a jeep loredo?'), ('2005 jeep Cherokee yellow exclamation light?', 'What does the yellow light mean when it turns on on your 2005 jeep loredo?'), ('2005 jeep Cherokee yellow exclamation light?', 'What is a yellow horseshoe gage light mean?'), ('2005 jeep Cherokee yellow exclamation light?', 'What is the exclaimation point on the instrument panel mean on a 2005 jeep grand cherokee?'), ('2005 jeep Cherokee yellow exclamation light?', 'What is the yellow exclamation point light in a 4 runner 2006?'), ('2005 jeep Cherokee yellow exclamation light?', 'Why did a light in dashboard of  ...
# [('2005 jeep Cherokee yellow exclamation light?', '2005 jeep grand cherokee dashboard symbols?'), ('2005 jeep Cherokee yellow exclamation light?', '2007 jeep cherokee exclamation point light in dashboard?'), ('2005 jeep Cherokee yellow exclamation light?', 'Dashboard lights on 2005 jeep grand cherokee?'), ('2005 jeep Cherokee yellow exclamation light?', 'Exclamation point horseshoe?'), ('2005 jeep Cherokee yellow exclamation light?', 'Exclamation point with a crooked line under it on a 2004 jeep laredo mean?'), ('2005 jeep Cherokee yellow exclamation light?', 'How do you change dashboard light on 2005 jeep?'), ('2005 jeep Cherokee yellow exclamation light?', 'Jeep grand cherokee horseshoe?'), ('2005 jeep Cherokee yellow exclamation light?', 'Light on dashboard exclamation point jeep cherokee?'), ('2005 jeep Cherokee yellow exclamation light?', 'On a 2002 ford windstar you have a yellow light on that looks like a horseshoe with an exclamation in it Does anyone know what it is?'), ('2005 jeep Cherokee yellow exclamation light?', 'On a 2005 Jeep Grand Cherokee what does the yellow dashboard light that looks like a horseshoe with a exclamation mark in it?')]
#                                       question1  \
# 0  2005 jeep Cherokee yellow exclamation light?
# 1  2005 jeep Cherokee yellow exclamation light?
# 2  2005 jeep Cherokee yellow exclamation light?
# 3  2005 jeep Cherokee yellow exclamation light?
# 4  2005 jeep Cherokee yellow exclamation light?
# 5  2005 jeep Cherokee yellow exclamation light?
# 6  2005 jeep Cherokee yellow exclamation light?
# 7  2005 jeep Cherokee yellow exclamation light?
# 8  2005 jeep Cherokee yellow exclamation light?
# 9  2005 jeep Cherokee yellow exclamation light?
#
#                                            question2
# 0        2005 jeep grand cherokee dashboard symbols?
# 1  2007 jeep cherokee exclamation point light in ...
# 2      Dashboard lights on 2005 jeep grand cherokee?
# 3                       Exclamation point horseshoe?
# 4  Exclamation point with a crooked line under it...
# 5    How do you change dashboard light on 2005 jeep?
# 6                     Jeep grand cherokee horseshoe?
# 7  Light on dashboard exclamation point jeep cher...
# 8  On a 2002 ford windstar you have a yellow ligh...
# 9  On a 2005 Jeep Grand Cherokee what does the ye...

# %%
# Out:
# 1300
