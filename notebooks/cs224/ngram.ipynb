# %%
import os 

def read_text_file(path,filename):
    fullpath = os.path.join(path,filename)
    if not os.path.exists(fullpath):
        print("Could not load text file!")
        return
    
    file = open(fullpath,'r')
    return file.read()

text = read_text_file("datasets/","lorax.txt")

# %%
from sklearn.feature_extraction.text import CountVectorizer 

vectorizer = CountVectorizer(ngram_range=(3,3))
analyzer = vectorizer.build_analyzer()
trigrams = analyzer(text)

# %%
# Out:
# ['at the far',
#  'the far end',
#  'far end of',
#  'end of town',
#  'of town where',
#  'town where the',
#  'where the grickle',
#  'the grickle grass',
#  'grickle grass grows',
#  'grass grows and',
#  'grows and the',
#  'and the wind',
#  'the wind smells',
#  'wind smells slow',
#  'smells slow and',
#  'slow and sour',
#  'and sour when',
#  'sour when it',
#  'when it blows',
#  'it blows and',
#  'blows and no',
#  'and no birds',
#  'no birds ever',
#  'birds ever sing',
#  'ever sing excepting',
#  'sing excepting old',
#  'excepting old crows',
#  'old crows is',
#  'crows is the',
#  'is the street',
#  'the street of',
#  'street of the',
#  'of the lifted',
#  'the lifted lorax',
#  'lifted lorax and',
#  'lorax and deep',
#  'and deep in',
#  'deep in the',
#  'in the grickle',
#  'the grickle grass',
#  'grickle grass some',
#  'grass some people',
#  'some people say',
#  'people say if',
#  'say if you',
#  'if you look',
#  'you look deep',
#  'look deep enough',
#  'deep enough you',
#  'enough you can',
#  'you can still',
#  'can still see',
#  'still see today',
#  'see today where',
#  'today where the',
#  'where the lorax',
#  'the lorax once',
#  'lorax once stood',
#  'once stood just',
#  'stood just as',
#  'just as long',
#  'as long as',
#  'long as it',
#  'as it could',
#  'it could before',
#  'could before somebody',
#  'before somebody lifted',
#  'somebody lifted the',
#  'lifted the lorax',
#  'the lorax away',
#  'lorax away what',
#  'away what was',
#  'what was the',
#  'was the lorax',
#  'the lorax any',
#  'lorax any why',
#  'any why was',
#  'why was it',
#  'was it there',
#  'it there and',
#  'there and why',
#  'and why was',
#  'why was it',
#  'was it lifted',
#  'it lifted and',
#  'lifted and taken',
#  'and taken somewhere',
#  'taken somewhere from',
#  'somewhere from the',
#  'from the far',
#  'the far end',
#  'far end of',
#  'end of town',
#  'of town where',
#  'town where the',
#  'where the grickle',
#  'the grickle grass',
#  'grickle grass grows',
#  'grass grows the',
#  'grows the old',
#  'the old once',
#  'old once ler',
#  'once ler still',
#  'ler still lives',
#  'still lives here',
#  'lives here ask',
#  'here ask him',
#  'ask him he',
#  'him he knows',
#  'he knows you',
#  'knows you won',
#  'you won see',
#  'won see the',
#  'see the once',
#  'the once ler',
#  'once ler don',
#  'ler don knock',
#  'don knock at',
#  'knock at his',
#  'at his door',
#  'his door he',
#  'door he stays',
#  'he stays in',
#  'stays in his',
#  'in his lerkim',
#  'his lerkim on',
#  'lerkim on top',
#  'on top of',
#  'top of his',
#  'of his store',
#  'his store he',
#  'store he stays',
#  'he stays in',
#  'stays in his',
#  'in his lerkim',
#  'his lerkim cold',
#  'lerkim cold under',
#  'cold under the',
#  'under the floor',
#  'the floor where',
#  'floor where he',
#  'where he makes',
#  'he makes his',
#  'makes his own',
#  'his own clothes',
#  'own clothes out',
#  'clothes out of',
#  'out of miff',
#  'of miff muffered',
#  'miff muffered moof',
#  'muffered moof and',
#  'moof and on',
#  'and on special',
#  'on special dank',
#  'special dank midnights',
#  'dank midnights in',
#  'midnights in august',
#  'in august he',
#  'august he peeks',
#  'he peeks out',
#  'peeks out of',
#  'out of the',
#  'of the shutters',
#  'the shutters and',
#  'shutters and sometimes',
#  'and sometimes he',
#  'sometimes he speaks',
#  'he speaks and',
#  'speaks and tells',
#  'and tells how',
#  'tells how the',
#  'how the lorax',
#  'the lorax was',
#  'lorax was lifted',
#  'was lifted away',
#  'lifted away he',
#  'away he ll',
#  'he ll tell',
#  'll tell you',
#  'tell you perhaps',
#  'you perhaps if',
#  'perhaps if you',
#  'if you re',
#  'you re willing',
#  're willing to',
#  'willing to pay',
#  'to pay on',
#  'pay on the',
#  'on the end',
#  'the end of',
#  'end of rope',
#  'of rope he',
#  'rope he lets',
#  'he lets down',
#  'lets down tin',
#  'down tin pail',
#  'tin pail and',
#  'pail and you',
#  'and you have',
#  'you have to',
#  'have to toss',
#  'to toss in',
#  'toss in fifteen',
#  'in fifteen cents',
#  'fifteen cents and',
#  'cents and nail',
#  'and nail and',
#  'nail and the',
#  'and the shell',
#  'the shell of',
#  'shell of great',
#  'of great great',
#  'great great great',
#  'great great grandfather',
#  'great grandfather snail',
#  'grandfather snail then',
#  'snail then he',
#  'then he pulls',
#  'he pulls up',
#  'pulls up the',
#  'up the pail',
#  'the pail makes',
#  'pail makes most',
#  'makes most careful',
#  'most careful count',
#  'careful count to',
#  'count to see',
#  'to see if',
#  'see if you',
#  'if you ve',
#  'you ve paid',
#  've paid him',
#  'paid him the',
#  'him the proper',
#  'the proper amount',
#  'proper amount then',
#  'amount then he',
#  'then he hides',
#  'he hides what',
#  'hides what you',
#  'what you paid',
#  'you paid him',
#  'paid him away',
#  'him away in',
#  'away in his',
#  'in his snuvv',
#  'his snuvv his',
#  'snuvv his secret',
#  'his secret strange',
#  'secret strange hole',
#  'strange hole in',
#  'hole in his',
#  'in his gruvvulous',
#  'his gruvvulous glove',
#  'gruvvulous glove then',
#  'glove then he',
#  'then he grunts',
#  'he grunts will',
#  'grunts will call',
#  'will call you',
#  'call you by',
#  'you by whisper',
#  'by whisper ma',
#  'whisper ma phone',
#  'ma phone for',
#  'phone for the',
#  'for the secrets',
#  'the secrets tell',
#  'secrets tell you',
#  'tell you are',
#  'you are for',
#  'are for your',
#  'for your ears',
#  'your ears alone',
#  'ears alone slupp',
#  'alone slupp down',
#  'slupp down slupps',
#  'down slupps the',
#  'slupps the whisper',
#  'the whisper ma',
#  'whisper ma phone',
#  'ma phone to',
#  'phone to your',
#  'to your ear',
#  'your ear and',
#  'ear and the',
#  'and the old',
#  'the old once',
#  'old once ler',
#  'once ler whispers',
#  'ler whispers are',
#  'whispers are not',
#  'are not very',
#  'not very clear',
#  'very clear since',
#  'clear since they',
#  'since they have',
#  'they have to',
#  'have to come',
#  'to come down',
#  'come down through',
#  'down through snergelly',
#  'through snergelly hose',
#  'snergelly hose and',
#  'hose and he',
#  'and he sounds',
#  'he sounds as',
#  'sounds as if',
#  'as if he',
#  'if he had',
#  'he had smallish',
#  'had smallish bees',
#  'smallish bees up',
#  'bees up his',
#  'up his nose',
#  'his nose now',
#  'nose now ll',
#  'now ll tell',
#  'll tell you',
#  'tell you he',
#  'you he says',
#  'he says with',
#  'says with his',
#  'with his teeth',
#  'his teeth sounding',
#  'teeth sounding gray',
#  'sounding gray how',
#  'gray how the',
#  'how the lorax',
#  'the lorax got',
#  'lorax got lifted',
#  'got lifted and',
#  'lifted and taken',
#  'and taken away',
#  'taken away it',
#  'away it all',
#  'it all started',
#  'all started way',
#  'started way back',
#  'way back such',
#  'back such long',
#  'such long long',
#  'long long time',
#  'long time back',
#  'time back way',
#  'back way back',
#  'way back in',
#  'back in the',
#  'in the days',
#  'the days when',
#  'days when the',
#  'when the grass',
#  'the grass was',
#  'grass was still',
#  'was still green',
#  'still green and',
#  'green and the',
#  'and the pond',
#  'the pond was',
#  'pond was still',
#  'was still wet',
#  'still wet and',
#  'wet and the',
#  'and the clouds',
#  'the clouds were',
#  'clouds were still',
#  'were still clean',
#  'still clean and',
#  'clean and the',
#  'and the song',
#  'the song of',
#  'song of the',
#  'of the swomee',
#  'the swomee swans',
#  'swomee swans rang',
#  'swans rang out',
#  'rang out in',
#  'out in space',
#  'in space one',
#  'space one morning',
#  'one morning came',
#  'morning came to',
#  'came to this',
#  'to this glorious',
#  'this glorious place',
#  'glorious place and',
#  'place and first',
#  'and first saw',
#  'first saw the',
#  'saw the trees',
#  'the trees the',
#  'trees the truffula',
#  'the truffula trees',
#  'truffula trees the',
#  'trees the bright',
#  'the bright colored',
#  'bright colored tufts',
#  'colored tufts of',
#  'tufts of the',
#  'of the truffula',
#  'the truffula trees',
#  'truffula trees mile',
#  'trees mile after',
#  'mile after mile',
#  'after mile in',
#  'mile in the',
#  'in the fresh',
#  'the fresh morning',
#  'fresh morning breeze',
#  'morning breeze and',
#  'breeze and under',
#  'and under the',
#  'under the trees',
#  'the trees saw',
#  'trees saw brown',
#  'saw brown bar',
#  'brown bar ba',
#  'bar ba loots',
#  'ba loots frisking',
#  'loots frisking about',
#  'frisking about in',
#  'about in their',
#  'in their bar',
#  'their bar ba',
#  'bar ba loot',
#  'ba loot suits',
#  'loot suits as',
#  'suits as the',
#  'as the played',
#  'the played in',
#  'played in the',
#  'in the shade',
#  'the shade and',
#  'shade and ate',
#  'and ate truffula',
#  'ate truffula fruits',
#  'truffula fruits from',
#  'fruits from the',
#  'from the rippulous',
#  'the rippulous pond',
#  'rippulous pond came',
#  'pond came the',
#  'came the comfortable',
#  'the comfortable sound',
#  'comfortable sound of',
#  'sound of the',
#  'of the humming',
#  'the humming fish',
#  'humming fish humming',
#  'fish humming while',
#  'humming while splashing',
#  'while splashing around',
#  'splashing around but',
#  'around but those',
#  'but those trees',
#  'those trees those',
#  'trees those trees',
#  'those trees those',
#  'trees those truffula',
#  'those truffula trees',
#  'truffula trees all',
#  'trees all my',
#  'all my life',
#  'my life been',
#  'life been searching',
#  'been searching for',
#  'searching for trees',
#  'for trees such',
#  'trees such as',
#  'such as these',
#  'as these the',
#  'these the touch',
#  'the touch of',
#  'touch of their',
#  'of their tufts',
#  'their tufts was',
#  'tufts was much',
#  'was much softer',
#  'much softer than',
#  'softer than silk',
#  'than silk and',
#  'silk and they',
#  'and they had',
#  'they had the',
#  'had the sweet',
#  'the sweet smell',
#  'sweet smell of',
#  'smell of fresh',
#  'of fresh butterfly',
#  'fresh butterfly milk',
#  'butterfly milk felt',
#  'milk felt great',
#  'felt great leaping',
#  'great leaping of',
#  'leaping of joy',
#  'of joy in',
#  'joy in my',
#  'in my heart',
#  'my heart knew',
#  'heart knew just',
#  'knew just what',
#  'just what do',
#  'what do unloaded',
#  'do unloaded my',
#  'unloaded my cart',
#  'my cart in',
#  'cart in no',
#  'in no time',
#  'no time at',
#  'time at all',
#  'at all had',
#  'all had built',
#  'had built small',
#  'built small shop',
#  'small shop then',
#  'shop then chopped',
#  'then chopped down',
#  'chopped down truffula',
#  'down truffula tree',
#  'truffula tree with',
#  'tree with one',
#  'with one chop',
#  'one chop and',
#  'chop and with',
#  'and with great',
#  'with great skillful',
#  'great skillful skill',
#  'skillful skill and',
#  'skill and with',
#  'and with great',
#  'with great speedy',
#  'great speedy speed',
#  'speedy speed took',
#  'speed took the',
#  'took the soft',
#  'the soft tuft',
#  'soft tuft and',
#  'tuft and knitted',
#  'and knitted thneed',
#  'knitted thneed the',
#  'thneed the instant',
#  'the instant finished',
#  'instant finished heard',
#  'finished heard ga',
#  'heard ga zump',
#  'ga zump looked',
#  'zump looked saw',
#  'looked saw something',
#  'saw something pop',
#  'something pop out',
#  'pop out of',
#  'out of the',
#  'of the stump',
#  'the stump of',
#  'stump of the',
#  'of the tree',
#  'the tree chopped',
#  'tree chopped down',
#  'chopped down it',
#  'down it was',
#  'it was sort',
#  'was sort of',
#  'sort of man',
#  'of man describe',
#  'man describe him',
#  'describe him that',
#  'him that hard',
#  'that hard don',
#  'hard don know',
#  'don know if',
#  'know if can',
#  'if can he',
#  'can he was',
#  'he was shortish',
#  'was shortish and',
#  'shortish and oldish',
#  'and oldish and',
#  'oldish and brownish',
#  'and brownish and',
#  'brownish and mossy',
#  'and mossy and',
#  'mossy and he',
#  'and he spoke',
#  'he spoke with',
#  'spoke with voice',
#  'with voice that',
#  'voice that was',
#  'that was sharpish',
#  'was sharpish and',
#  'sharpish and bossy',
#  'and bossy mister',
#  'bossy mister he',
#  'mister he said',
#  'he said with',
#  'said with sawdusty',
#  'with sawdusty sneeze',
#  'sawdusty sneeze am',
#  'sneeze am the',
#  'am the lorax',
#  'the lorax speak',
#  'lorax speak for',
#  'speak for the',
#  'for the trees',
#  'the trees speak',
#  'trees speak for',
#  'speak for the',
#  'for the trees',
#  'the trees for',
#  'trees for the',
#  'for the trees',
#  'the trees have',
#  'trees have no',
#  'have no tongues',
#  'no tongues and',
#  'tongues and asking',
#  'and asking you',
#  'asking you sir',
#  'you sir at',
#  'sir at the',
#  'at the top',
#  'the top of',
#  'top of my',
#  'of my lungs',
#  'my lungs he',
#  'lungs he was',
#  'he was very',
#  'was very upset',
#  'very upset as',
#  'upset as he',
#  'as he shouted',
#  'he shouted and',
#  'shouted and puffed',
#  'and puffed what',
#  'puffed what that',
#  'what that thing',
#  'that thing you',
#  'thing you ve',
#  'you ve made',
#  've made out',
#  'made out of',
#  'out of my',
#  'of my truffula',
#  'my truffula tuft',
#  'truffula tuft look',
#  'tuft look lorax',
#  'look lorax said',
#  'lorax said there',
#  'said there no',
#  'there no cause',
#  'no cause for',
#  'cause for alarm',
#  'for alarm chopped',
#  'alarm chopped just',
#  'chopped just one',
#  'just one tree',
#  'one tree am',
#  'tree am doing',
#  'am doing no',
#  'doing no harm',
#  'no harm being',
#  'harm being quite',
#  'being quite useful',
#  'quite useful this',
#  'useful this thing',
#  'this thing is',
#  'thing is thneed',
#  'is thneed thneed',
#  'thneed thneed fine',
#  'thneed fine something',
#  'fine something that',
#  'something that all',
#  'that all people',
#  'all people need',
#  'people need it',
#  'need it shirt',
#  'it shirt it',
#  'shirt it sock',
#  'it sock it',
#  'sock it glove',
#  'it glove it',
#  'glove it hat',
#  'it hat but',
#  'hat but it',
#  'but it has',
#  'it has other',
#  'has other uses',
#  'other uses yes',
#  'uses yes far',
#  'yes far beyond',
#  'far beyond that',
#  'beyond that you',
#  'that you can',
#  'you can use',
#  'can use it',
#  'use it for',
#  'it for carpets',
#  'for carpets for',
#  'carpets for pillows',
#  'for pillows for',
#  'pillows for sheets',
#  'for sheets or',
#  'sheets or curtains',
#  'or curtains or',
#  'curtains or covers',
#  'or covers for',
#  'covers for bicycle',
#  'for bicycle seats',
#  'bicycle seats the',
#  'seats the lorax',
#  'the lorax said',
#  'lorax said sir',
#  'said sir you',
#  'sir you are',
#  'you are crazy',
#  'are crazy with',
#  'crazy with greed',
#  'with greed there',
#  'greed there is',
#  'there is no',
#  'is no one',
#  'no one on',
#  'one on earth',
#  'on earth who',
#  'earth who would',
#  'who would buy',
#  'would buy that',
#  'buy that fool',
#  'that fool thneed',
#  'fool thneed but',
#  'thneed but the',
#  'but the very',
#  'the very next',
#  'very next minute',
#  'next minute proved',
#  'minute proved he',
#  'proved he was',
#  'he was wrong',
#  'was wrong for',
#  'wrong for just',
#  'for just at',
#  'just at that',
#  'at that minute',
#  'that minute chap',
#  'minute chap came',
#  'chap came along',
#  'came along and',
#  'along and he',
#  'and he thought',
#  'he thought that',
#  'thought that the',
#  'that the thneed',
#  'the thneed had',
#  'thneed had knitted',
#  'had knitted was',
#  'knitted was great',
#  'was great he',
#  'great he happily',
#  'he happily bought',
#  'happily bought it',
#  'bought it for',
#  'it for three',
#  'for three ninety',
#  'three ninety eight',
#  'ninety eight laughed',
#  'eight laughed at',
#  'laughed at the',
#  'at the lorax',
#  'the lorax you',
#  'lorax you poor',
#  'you poor stupid',
#  'poor stupid guy',
#  'stupid guy you',
#  'guy you never',
#  'you never can',
#  'never can tell',
#  'can tell what',
#  'tell what some',
#  'what some people',
#  'some people will',
#  'people will buy',
#  'will buy repeat',
#  'buy repeat cried',
#  'repeat cried the',
#  'cried the lorax',
#  'the lorax speak',
#  'lorax speak for',
#  'speak for the',
#  'for the trees',
#  'the trees busy',
#  'trees busy told',
#  'busy told him',
#  'told him shut',
#  'him shut up',
#  'shut up if',
#  'up if you',
#  'if you please',
#  'you please rushed',
#  'please rushed cross',
#  'rushed cross the',
#  'cross the room',
#  'the room and',
#  'room and in',
#  'and in no',
#  'in no time',
#  'no time at',
#  'time at all',
#  'at all built',
#  'all built radiophone',
#  'built radiophone put',
#  'radiophone put in',
#  'put in quick',
#  'in quick call',
#  'quick call called',
#  'call called all',
#  'called all my',
#  'all my brothers',
#  'my brothers and',
#  'brothers and uncles',
#  'and uncles and',
#  'uncles and aunts',
#  'and aunts and',
#  'aunts and said',
#  'and said listen',
#  'said listen here',
#  'listen here here',
#  'here here wonderful',
#  'here wonderful chance',
#  'wonderful chance for',
#  'chance for the',
#  'for the whole',
#  'the whole once',
#  'whole once ler',
#  'once ler family',
#  'ler family to',
#  'family to get',
#  'to get mighty',
#  'get mighty rich',
#  'mighty rich get',
#  'rich get over',
#  'get over here',
#  'over here fast',
#  'here fast take',
#  'fast take the',
#  'take the road',
#  'the road to',
#  'road to north',
#  'to north nitch',
#  'north nitch turn',
#  'nitch turn left',
#  'turn left at',
#  'left at weehawken',
#  'at weehawken sharp',
#  'weehawken sharp right',
#  'sharp right at',
#  'right at south',
#  'at south stitch',
#  'south stitch and',
#  'stitch and in',
#  'and in no',
#  'in no time',
#  'no time at',
#  'time at all',
#  'at all in',
#  'all in the',
#  'in the factory',
#  'the factory built',
#  'factory built the',
#  'built the whole',
#  'the whole once',
#  'whole once ler',
#  'once ler family',
#  'ler family was',
#  'family was working',
#  'was working full',
#  'working full tilt',
#  'full tilt we',
#  'tilt we were',
#  'we were all',
#  'were all knitting',
#  'all knitting thneed',
#  'knitting thneed just',
#  'thneed just as',
#  'just as busy',
#  'as busy as',
#  'busy as bees',
#  'as bees to',
#  'bees to the',
#  'to the sound',
#  'the sound of',
#  'sound of the',
#  'of the chopping',
#  'the chopping of',
#  'chopping of truffula',
#  'of truffula trees',
#  'truffula trees then',
#  'trees then oh',
#  'then oh baby',
#  'oh baby oh',
#  'baby oh how',
#  'oh how my',
#  'how my business',
#  'my business did',
#  'business did grow',
#  'did grow now',
#  'grow now chopping',
#  'now chopping one',
#  'chopping one tree',
#  'one tree at',
#  'tree at time',
#  'at time was',
#  'time was too',
#  'was too slow',
#  'too slow so',
#  'slow so quickly',
#  'so quickly invented',
#  'quickly invented my',
#  'invented my super',
#  'my super axe',
#  'super axe hacker',
#  'axe hacker which',
#  'hacker which whacked',
#  'which whacked off',
#  'whacked off four',
#  'off four truffula',
#  'four truffula trees',
#  'truffula trees at',
#  'trees at one',
#  'at one smacker',
#  'one smacker we',
#  'smacker we were',
#  'we were making',
#  'were making thneed',
#  'making thneed four',
#  'thneed four times',
#  'four times as',
#  'times as fast',
#  'as fast as',
#  'fast as before',
#  'as before and',
#  'before and that',
#  'and that lorax',
#  'that lorax he',
#  'lorax he didn',
#  'he didn show',
#  'didn show up',
#  'show up any',
#  'up any more',
#  'any more but',
#  'more but the',
#  'but the next',
#  'the next week',
#  'next week he',
#  'week he knocked',
#  'he knocked on',
#  'knocked on my',
#  'on my new',
#  'my new office',
#  'new office door',
#  'office door he',
#  'door he snapped',
#  'he snapped the',
#  'snapped the lorax',
#  'the lorax who',
#  'lorax who speaks',
#  'who speaks for',
#  'speaks for the',
#  'for the trees',
#  'the trees which',
#  'trees which you',
#  'which you seem',
#  'you seem to',
#  'seem to be',
#  'to be chopping',
#  'be chopping as',
#  'chopping as fast',
#  'as fast as',
#  'fast as you',
#  'as you please',
#  'you please but',
#  'please but also',
#  'but also in',
#  'also in charge',
#  'in charge of',
#  'charge of the',
#  'of the brown',
#  'the brown bar',
#  'brown bar ba',
#  'bar ba loots',
#  'ba loots who',
#  'loots who played',
#  'who played in',
#  'played in the',
#  'in the shade',
#  'the shade in',
#  'shade in their',
#  'in their bar',
#  'their bar ba',
#  'bar ba loot',
#  'ba loot suits',
#  'loot suits and',
#  ...]
